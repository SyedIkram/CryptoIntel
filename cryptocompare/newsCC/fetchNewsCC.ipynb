# %%
# Cache 120 sec = 2 min

import requests
import pandas as pd
import json
import time
import os
import datetime
from pandas.io.json import json_normalize
from cassandra import ConsistencyLevel
from cassandra.cluster import Cluster
from cassandra.query import SimpleStatement
from pytz import timezone

# %%
class fetchNewsCC:
    def __init__(self,url,api_key='',sort_order='Latest'):
        if api_key:
            url += '&api_key={}'.format(api_key)
        if sort_order:
            url += '&sortOrder={}'.format(sort_order)
        self.api_key = api_key
        self.url = url
        print("URL Created: " + self.url)
        
    def getJSON(self):
        req=requests.get(self.url)
        json_obj = req.json()
        return json_obj
    
    def formatPD(self,newsPD,col_name):
        newsPD = newsPD.rename(index=str, columns={"source_info.img": "source_info_img",\
                                           "source_info.name":"source_info_name","source_info.lang":"source_info_lang"})
        newsPD['tags'] = newsPD['tags'].apply(lambda x: x.split('|'))
        newsPD['categories'] = newsPD['categories'].apply(lambda x: x.split('|'))
        newsPD['published_on'] = newsPD['published_on'].apply(lambda x: self.convertToPstSeq(x))
        newsPD['source_info_name'] = newsPD['source_info_name'].fillna('unknown')
        newsPD['source_info_lang'] = newsPD['source_info_lang'].fillna('unknown')
        newsPD['source_info_img'] = newsPD['source_info_img'].fillna('unknown')
        newsPD['downvotes'] = newsPD['downvotes'].fillna(0)
        newsPD['guid'] = newsPD['guid'].fillna('unknown')
        newsPD['imageurl'] = newsPD['imageurl'].fillna('not_found')
        newsPD['lang'] = newsPD['lang'].fillna('EN')
        newsPD['source'] = newsPD['source'].fillna('unknown')
        newsPD['upvotes'] = newsPD['upvotes'].fillna(0)
        newsPD['url'] = newsPD['url'].fillna('not_found')
        return newsPD
    
    def jsonToPandas(self,json_obj):
        pd = json_normalize(json_obj)
        return pd
    
    def createSessionCassandra(self,key_space):
        self.cluster = Cluster(['127.0.0.1'],load_balancing_policy=None)
        self.session = self.cluster.connect()
        self.session.set_keyspace(key_space)
        
    def convertToPstSeq(self,inp_time):
        return datetime.datetime.fromtimestamp(int(inp_time)).astimezone(timezone('US/Pacific')).strftime('%Y%m%d%H%M%S')
        
    def checkTable(self,table_name):        
        self.session.execute("""CREATE TABLE IF NOT EXISTS """ + table_name + """ (
            body TEXT,
            categories list<text>,
            downvotes TEXT,
            guid TEXT,
            id INT,
            imageurl TEXT,
            lang TEXT,
            published_on TEXT,
            source TEXT,
            source_info_img TEXT,
            source_info_lang TEXT,
            source_info_name TEXT,
            tags list<text>,
            title TEXT,
            upvotes INT,
            url TEXT,
            sortmentainer INT,
            PRIMARY KEY(sortmentainer,published_on,id))
            WITH CLUSTERING ORDER BY (published_on DESC);
            """)        
    
    def pdToCassandra(self,table_name,pd,sorter):
        self.checkTable(table_name)
        query = """INSERT INTO """+ table_name +""" (
        sortmentainer,body,categories,downvotes,guid,id,imageurl,lang,
        published_on,source,source_info_img,source_info_lang,source_info_name,
        tags,title,upvotes,url) VALUES
        (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)"""
        prepared = self.session.prepare(query)
        for index, df_iter in pd.iterrows():
            self.session.execute(prepared,\
                             (int(sorter),df_iter['body'], df_iter['categories'], df_iter['downvotes'], df_iter['guid'], int(df_iter['id']),\
                             df_iter['imageurl'], df_iter['lang'], str(df_iter['published_on']), df_iter['source'], df_iter['source_info_img'],\
                             df_iter['source_info_lang'], df_iter['source_info_name'],df_iter['tags'], df_iter['title'], int(df_iter['upvotes']),\
                             df_iter['url']))

# %%
api_key = '23489088ccc5e95cef763cbedd2d27588a979595edb097f53f40ad7d76239d41'
sortOrder = 'Latest'
categories = 'ALL_NEWS_CATEGORIES'
key_space = 'crypton'

# %%
#Fetch latest News
url = 'https://min-api.cryptocompare.com/data/v2/news/?lang=EN'
while (True):
    F2 = fetchNewsCC(url)
    jsonNews = F2.getJSON()
    # print(jsonNews)
    newsPD = F2.jsonToPandas(jsonNews['Data'])
    newsPD = F2.formatPD(newsPD,'published_on')
    F2.createSessionCassandra(key_space)
    F2.pdToCassandra('news_cc',newsPD,1)
    time.sleep(120)
# Out:
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&sortOrder=Latest
# 20190322173016
# 20190322171529
# 20190322171500
# 20190322170043
# 20190322164826
# 20190322163347
# 20190322162000
# 20190322160029
# 20190322155000
# 20190322153035
# 20190322152306
# 20190322151148
# 20190322150044
# 20190322145341
# 20190322145000
# 20190322144013
# 20190322144000
# 20190322143022
# 20190322141526
# 20190322140500
# 20190322140004
# 20190322140003
# 20190322134548
# 20190322134320
# 20190322134229
# 20190322133056
# 20190322133022
# 20190322132000
# 20190322131654
# 20190322131217
# 20190322130200
# 20190322130035
# 20190322125500
# 20190322124911
# 20190322124440
# 20190322123029
# 20190322122507
# 20190322121900
# 20190322121534
# 20190322120050
# 20190322120025
# 20190322115900
# 20190322115323
# 20190322114718
# 20190322114032
# 20190322113400
# 20190322113103
# 20190322113014
# 20190322111013
# 20190322110039
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-025449f76cc9> in <module>
#       9     F2.createSessionCassandra(key_space)
#      10     F2.pdToCassandra('news_cc',newsPD,1)
# ---> 11     time.sleep(120)
#
# KeyboardInterrupt:

# %%
from datetime import timedelta, date

list_datre_range = []
pattern = '%Y-%m-%d %H:%M:%S'

def daterange(start_date, end_date):
    for n in range(int ((end_date - start_date).days)):
        yield start_date + timedelta(n)

start_date = date(2018, 12, 31)
end_date = date(2019, 3, 21)
for single_date in daterange(start_date, end_date):
    date_time = str(single_date.strftime("%Y-%m-%d") + ' 00:00:00')
    list_datre_range.append(int(time.mktime(time.strptime(date_time, pattern))))

# %%
# list_datre_range

url = 'https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs='
for ts in list_datre_range:
    F2 = fetchNewsCC(url + str(ts))
    jsonNews = F2.getJSON()
    # print(jsonNews)
    newsPD = F2.jsonToPandas(jsonNews['Data'])
    newsPD = F2.formatPD(newsPD,'published_on')
    F2.createSessionCassandra(key_space)
    F2.pdToCassandra('news_cc',newsPD,0)
#     time.sleep(2)
# Out:
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1546243200&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1546329600&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1546416000&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1546502400&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1546588800&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1546675200&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1546761600&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1546848000&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1546934400&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1547020800&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1547107200&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1547193600&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1547280000&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1547366400&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1547452800&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1547539200&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1547625600&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1547712000&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1547798400&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1547884800&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1547971200&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1548057600&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1548144000&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1548230400&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1548316800&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1548403200&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1548489600&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1548576000&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1548662400&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1548748800&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1548835200&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1548921600&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1549008000&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1549094400&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1549180800&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1549267200&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1549353600&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1549440000&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1549526400&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1549612800&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1549699200&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1549785600&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1549872000&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1549958400&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1550044800&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1550131200&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1550217600&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1550304000&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1550390400&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1550476800&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1550563200&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1550649600&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1550736000&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1550822400&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1550908800&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1550995200&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1551081600&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1551168000&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1551254400&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1551340800&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1551427200&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1551513600&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1551600000&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1551686400&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1551772800&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1551859200&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1551945600&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1552032000&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1552118400&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1552204800&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1552287600&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1552374000&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1552460400&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1552546800&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1552633200&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1552719600&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1552806000&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1552892400&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1552978800&sortOrder=Latest
# URL Created: https://min-api.cryptocompare.com/data/v2/news/?lang=EN&lTs=1553065200&sortOrder=Latest

# %%
cluster = Cluster(['127.0.0.1'],load_balancing_policy=None)
session = cluster.connect()
session.set_keyspace(key_space)

# %%
# Cassandra to CSV
def cassandraToCsv():
    query = "SELECT * FROM news_cc WHERE sortmentainer=0;"
    future = session.execute(query)
    
    return future
    
df = pd.DataFrame(list(cassandraToCsv()))
df['date'] = df['published_on'].apply(lambda x: x[:4] + '-' + x[4:6]+ '-' + x[6:8] )
# df.to_csv('allnews.csv',index=False)

# %%
df = df
df['categoriesStr'] = df['categories'].apply(lambda x: ' '.join(str(e) for e in x))
df = df.loc[df.categoriesStr.str.contains('BTC')]
df.to_csv('btcnews0.csv',index=False)
